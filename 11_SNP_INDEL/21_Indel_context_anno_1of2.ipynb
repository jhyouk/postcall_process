# %%
# for ID signature
# python2.7

import os,sys,pysam,gzip,collections
from numpy import median


def ID_repeat(input_line,ref_fasta):
    input_split = input_line.split('\t')
    input_chr = input_split[0]
    input_pos = long(input_split[1])
    
    input_ref = input_split[3]
    input_alt = input_split[4]
    
    if len(input_ref) == 1: # for small insertion
        ru = input_alt[1:]
        rc = 0
        
        while rc<5:
            if ref_fasta.fetch(input_chr,input_pos+len(ru)*rc,input_pos+len(ru)*(rc+1)) == ru:
                rc+=1
                #print ref_fasta.fetch(input_chr,input_pos+len(ru)*rc,input_pos+len(ru)*(rc+1))
            else:
                break
        #print ref_fasta.fetch(input_chr,input_pos-1,input_pos) + 'qwe'
        return ['insertion',str(ru),str(rc),'noMH']

    else: # for deletion    
        if len(input_ref) == 2:
            ru = input_ref[1:]
            rc = 0
            
            while rc<5:
                if ref_fasta.fetch(input_chr,input_pos+len(ru)*(rc+1),input_pos+len(ru)*(rc+2)) == ru:
                    rc+=1
                    #print ref_fasta.fetch(input_chr,input_pos+len(ru)*rc,input_pos+len(ru)*(rc+1))
                else:
                    break
            #print ref_fasta.fetch(input_chr,input_pos-2,input_pos) + 'qwe'
            return ['deletion',str(ru),str(rc+1),'noMH']            
            
            
        else:
            #print input_line
            ru = input_ref[1:]
            rc = 0
            #print ru
            #print ref_fasta.fetch(input_chr,input_pos+len(ru)*(rc+1),input_pos+len(ru)*(rc+2))
            
            if ref_fasta.fetch(input_chr,input_pos+len(ru)*(rc+1),input_pos+len(ru)*(rc+2)) == ru:
                while rc<5:
                    if ref_fasta.fetch(input_chr,input_pos+len(ru)*(rc+1),input_pos+len(ru)*(rc+2)) == ru:
                        rc+=1
                        #print ref_fasta.fetch(input_chr,input_pos+len(ru)*rc,input_pos+len(ru)*(rc+1))
                    else:
                        break
                #print ref_fasta.fetch(input_chr,input_pos-2,input_pos) + 'qwe'
                return ['deletion',str(ru),str(rc+1),'noMH']
            else: # microhomology check!
                rt_mh = 0
                lt_mh = 0
                for i in range(0,len(ru)):
                    if ref_fasta.fetch(input_chr,input_pos+len(ru),input_pos+len(ru)+1+i) == input_ref[1:1+1+i]:
                        rt_mh+=1
                    else:
                        break
                for j in range(0,len(ru)):
                    if ref_fasta.fetch(input_chr,input_pos-1-j,input_pos) == input_ref[-1-j:]:
                        lt_mh+=1
                    else:
                        break                                            
                if rt_mh == 0 & lt_mh ==0:
                    return ['deletion',str(ru),str(rc+1),'noMH']
                else:
                    #print input_line
                    return ['deletion',str(ru),'0',str(max(rt_mh,lt_mh))]
        
        
        
    
#start
import os, sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/")
file_list = []
#pre_list = []
for i in temp_list:
    if '_indel_filtered_strict.vcf' in i and '.anv' not in i:
        file_list.append("/home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/" + i)
print len(file_list)
#for i in file_list:
#    print i
#sys.exit(1)


#file_list = [sys.argv[1]]


for input_fn in file_list:
    print input_fn
    #chr_pos_list=[]
    input_file = open(input_fn)
    output_file = file(input_fn.replace(".vcf",".context_anno.vcf"),"w")
    input_line = input_file.readline().strip()
    while input_line[0:2] =='##':
        input_line = input_file.readline().strip()
    output_file.write(input_line+'\tID_signature_type;repeat_unit;repat_count;microhomology\n')
    input_line = input_file.readline().strip()
    
    mm=0
    while input_line:
        ref_fa='/home/users/jhyouk/99_reference/human/GRCh37/human_g1k_v37.fasta'
        r_file=pysam.FastaFile(ref_fa)
        if len(input_line.split('\t')[3]) > 11 or len(input_line.split('\t')[4]) > 11 :
            'blank'
        else:
            ID_list = ID_repeat(input_line,r_file)
            output_file.write(input_line + '\t' + ';'.join(ID_list) + '\n')

        input_line = input_file.readline().strip()


    output_file.close()
    
print 'THE END'
# Out:
# 405
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-03_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-18_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-05_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-17_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-24_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-09_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-10_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-18_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-03_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-01_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC16-03_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC16-02_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-09_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-06_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-09_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC18-09_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-16_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-14_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-02_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-14_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-21_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-01_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-02_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC19-05_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-15_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-08_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-20_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC19-19_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-02_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-13_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-06_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-22_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-08_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-12_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-20_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC16-05_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-05_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC20-05_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-23_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-11_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-19_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-07_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-23_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-01_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-23_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-15_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-19_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-21_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC18-20_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-06_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-05_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-22_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-13_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC19-09_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-10_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-22_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-08_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC19-11_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-24_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC20-12_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC19-03_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-07_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-07_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-12_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-03_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-11_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-17_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-04_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-08_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-16_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC17-01_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-07_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-04_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-04_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-04_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-24_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC18-03_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-10_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.vcf
# THE END

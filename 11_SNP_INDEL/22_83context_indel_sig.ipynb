# %%
#2nd part of indel_signature
#83 context

#'1bp_del'
#'1bp_ins'
#'2bp_del_repeat'
#'2bp_ins'
#'2bp_del_micohomology'

#start
import os, sys
temp_list = os.listdir("/home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/")
file_list = []
#pre_list = []
for i in temp_list:
    if '.context_anno.vcf' in i:
        file_list.append("/home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/" + i)
print len(file_list)
#sys.exit(1)
#file_list = [sys.argv[1]]

output_file_total = file("/home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/405_indel_total.txt","w")
n=0
for input_fn in file_list:   
    print input_fn
    input_file = file(input_fn)
    output_file = file(input_fn.replace(".vcf",".indel_spectrum.vcf"),"w")
    head_list = ['ID','d1c1', 'd1c2', 'd1c3', 'd1c4', 'd1c5', 'd1c6', 'd1t0', 'd1t1', 'd1t2', 'd1t3', 'd1t4', 'd1t5', 'i1c1', 'i1c2', 'i1c3', 'i1c4', 'i1c5', 'i1c6', 'i1t0', 'i1t1', 'i1t2', 'i1t3', 'i1t4', 'i1t5', 'd22_1', 'd22_2', 'd22_3', 'd22_4', 'd22_5', 'd22_6', 'd23_1', 'd23_2', 'd23_3', 'd23_4', 'd23_5', 'd23_6', 'd24_1', 'd24_2', 'd24_3', 'd24_4', 'd24_5', 'd24_6', 'd25_1', 'd25_2', 'd25_3', 'd25_4', 'd25_5', 'd25_6', 'i22_0', 'i22_1', 'i22_2', 'i22_3', 'i22_4', 'i22_5', 'i23_0', 'i23_1', 'i23_2', 'i23_3', 'i23_4', 'i23_5', 'i24_0', 'i24_1', 'i24_2', 'i24_3', 'i24_4', 'i24_5', 'i25_0', 'i25_1', 'i25_2', 'i25_3', 'i25_4', 'i25_5', 'mh2_1', 'mh3_1', 'mh3_2', 'mh4_1', 'mh4_2', 'mh4_3', 'mh5_1', 'mh5_2', 'mh5_3', 'mh5_4', 'mh5_5']
    output_file.write('\t'.join(head_list) + "\n")
    if n==0:
        output_file_total.write('\t'.join(head_list) + "\n")
        n+=1
    
    del_1bp = []
    ins_1bp = []
    del_2bp = []
    ins_2bp = []
    del_mh = []

    for i in range(0,12):
        del_1bp.append(0)
        ins_1bp.append(0)
    for i in range(0,24):    
        del_2bp.append(0)
        ins_2bp.append(0)
    for i in range(0,11):
        del_mh.append(0)

    input_line = input_file.readline().strip()
    input_line = input_file.readline().strip()

    while input_line:
        input_info = input_line.split('\t')[-1] ####
            
        info_split = input_info.split(';')

        if len(info_split[1]) == 1:
            if info_split[0] == 'deletion':
                homopolymer=min(int(info_split[2]),6)
                if info_split[1] == 'C' or info_split[1] == 'G':
                    del_1bp[0+homopolymer-1] += 1          
                else:
                    del_1bp[6+homopolymer-1] += 1  
            else:
                homopolymer=min(int(info_split[2]),5)
                if info_split[1] == 'C' or info_split[1] == 'G':
                    ins_1bp[0+homopolymer]+=1          
                else:
                    ins_1bp[6+homopolymer]+=1
        elif info_split[0] == 'insertion':
            ins_length = min(len(info_split[1]),5)
            homopolymer=min(int(info_split[2]),5)
            ins_2bp[6*(ins_length-2)+homopolymer]+=1

        else:
            if info_split[3] == 'noMH':
                del_length = min(len(info_split[1]),5)
                homopolymer=min(int(info_split[2]),6)        
                del_2bp[6*(del_length-2) + homopolymer-1] += 1
            else:
                del_length = min(len(info_split[1]),5)
                mh = min(int(info_split[3]),5)
                if del_length == 2:
                    del_mh[0] += 1
                elif del_length == 3:
                    del_mh[mh] += 1
                elif del_length == 4:
                    del_mh[3-1+mh] += 1
                else:
                    del_mh[6-1+mh] += 1
        input_line = input_file.readline().strip()

    temp_total = ""
    for i in del_1bp:
        temp_total = temp_total + '\t' + str(i)
    for i in ins_1bp:
        temp_total = temp_total + '\t' + str(i)
    for i in del_2bp:
        temp_total = temp_total + '\t' + str(i)
    for i in ins_2bp:
        temp_total = temp_total + '\t' + str(i)
    for i in del_mh:
        temp_total = temp_total + '\t' + str(i)
    
    input_id = ''
    if input_fn.split('/')[-1][0:2] == 'HC':
        input_id = input_fn.split('/')[-1].split('_indel')[0]
    elif input_fn.split('/')[-1][0:3] == 'JHY':
        input_id = input_fn.split('/')[-1].split('-')[2] + '-' + input_fn.split('/')[-1].split('-')[3].split('_')[0]
        
    output_file.write(input_id + temp_total + '\n')        
    output_file.close()  
    output_file_total.write(input_id + temp_total + '\n')

output_file_total.close()
print 'THE END'
# Out:
# 405
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC19-19_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-03_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-18_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-19_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-08_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-14_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-20_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC19-05_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-23_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-01_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-07_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC18-03_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-10_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC17-01_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-08_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-23_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-02_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-07_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-05_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-17_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-18_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-16_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-22_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-08_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-20_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-09_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-13_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-05_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-09_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-04_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-24_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-21_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-06_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-03_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-04_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-02_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-19_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-08_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC16-02_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-10_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-07_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-06_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-01_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-23_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-04_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-24_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-11_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-16_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-06_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC20-05_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-22_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-13_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-14_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC18-20_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC21-10_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC18-09_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC19-03_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-15_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-05_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC20-12_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-04_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-12_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC16-05_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-22_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-07_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-14_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-10_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-07_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-12_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC19-11_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-23_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-02_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-17_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC20-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-02_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-24_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-15_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC18-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC05-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-01_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC10-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-21_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-06_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC02-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-09_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC17-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-03_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC21-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-11_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC05-03_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC14-12_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC08-19_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC01-21_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-22_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-16_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC03-01_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC19-09_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-13_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-17_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-09_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC06-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC19-04_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC12-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-20_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC16-18_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC15-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC13-05_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-15_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/HC16-03_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC04-08_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# /home/users/jhyouk/14_colon_LINE1/11_SNP_INDEL/JHY-COL-HC09-11_blood-wgs-ILLUMINA.fmarked_indel_filtered_strict.context_anno.vcf
# THE END
